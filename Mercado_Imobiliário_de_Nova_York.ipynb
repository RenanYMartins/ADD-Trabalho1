# %% [markdown]
# <a href="https://colab.research.google.com/github/RenanYMartins/ADD-Trabalho1/blob/main/Mercado_Imobili%C3%A1rio_de_Nova_York.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade Avaliativa I - Análise de Dados do Mercado Imobiliário de Nova York

# %% [markdown]
# ## Setup Inicial
#
# Importando bibliotecas e conectando à base de dados.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy import stats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Análise de Dados/Trabalho I/data/07_mercado_imobiliário_ny.csv')

# %% [markdown]
# ## Visão Inicial dos Dados

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# 2                                   620 Sinclair Ave  Staten Island, NY 10312
# 3                            2 E 55th St Unit 908W33      Manhattan, NY 10022
# 4                                        5 E 64th St       New York, NY 10065
#
#                                         MAIN_ADDRESS  \
# 0             2 E 55th St Unit 803New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2            620 Sinclair AveStaten Island, NY 10312
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                      5 E 64th StNew York, NY 10065
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  New York        Manhattan  East 55th Street
# 1               United States  New York  New York County          New York
# 2               United States  New York  Richmond County     Staten Island
# 3               United States  New York  New York County          New York
# 4               United States  New York  New York County          New York
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  West 57th Street             217 W 57th St, New York, NY 10019, USA
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 4  East 64th Street               5 E 64th St, New York, NY 10065, USA
#
#     LATITUDE  LONGITUDE
# 0  40.761255 -73.974483
# 1  40.766393 -73.980991
# 2  40.541805 -74.196109
# 3  40.761398 -73.974613
# 4  40.767224 -73.969856

# %% [markdown]
# Vemos que os dados representam imóveis à venda disponíveis em Nova Iorque, com as seguintes propriedades:
#
# - `BROKERTITLE`: Título do corretor.
# - `TYPE`: Tipo do imóvel.
# - `PRICE`: Preço do imóvel.
# - `BEDS`: Número de quartos.
# - `BATH`: Número de banheiros.
# - `PROPERTYSQFT`: Área em $\mathrm{m}^2$.
# - `ADDRESS`: Endereço completo.
# - `STATE`: Estado (NY).
# - `MAIN_ADDRESS`: Endereço principal.
# - `ADMINISTRATIVE_AREA_LEVEL_2`: Área administrativa secundária.
# - `LOCALITY`: Localidade.
# - `SUBLOCALITY`: Sublocalidade.
# - `STREET_NAME`: Nome da rua.
# - `LONG_NAME`: Nome completo da localização.
# - `FORMATTED_ADDRESS`: Endereço formatado.
# - `LATITUDE`: Latitude geográfica.
# - `LONGITUDE`: Longitude geográfica.

# %%
print(f'A base contém {df.shape[0]} registros e {df.shape[1]} variáveis.')
# Out:
# A base contém 4801 registros e 17 variáveis.

# %%
df.isnull().sum().reset_index().rename(columns={0: "Quantidade de Nulos", "index": "Variável"})
# Out:
#                        Variável  Quantidade de Nulos
# 0                   BROKERTITLE                    0
# 1                          TYPE                    0
# 2                         PRICE                    0
# 3                          BEDS                    0
# 4                          BATH                    0
# 5                  PROPERTYSQFT                    0
# 6                       ADDRESS                    0
# 7                         STATE                    0
# 8                  MAIN_ADDRESS                    0
# 9   ADMINISTRATIVE_AREA_LEVEL_2                    0
# 10                     LOCALITY                    0
# 11                  SUBLOCALITY                    0
# 12                  STREET_NAME                    0
# 13                    LONG_NAME                    0
# 14            FORMATTED_ADDRESS                    0
# 15                     LATITUDE                    0
# 16                    LONGITUDE                    0

# %%
df.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  4.801000e+03  4801.000000  4801.000000   4801.000000  4801.000000
# mean   2.356940e+06     3.356801     2.373861   2184.207862    40.714227
# std    3.135525e+07     2.602315     1.946962   2377.140894     0.087676
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.639375
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726749
# 75%    1.495000e+06     4.000000     3.000000   2184.207862    40.771923
# max    2.147484e+09    50.000000    50.000000  65535.000000    40.912729
#
#          LONGITUDE
# count  4801.000000
# mean    -73.941601
# std       0.101082
# min     -74.253033
# 25%     -73.987143
# 50%     -73.949189
# 75%     -73.870638
# max     -73.702450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
#  13  LONG_NAME                    4801 non-null   object
#  14  FORMATTED_ADDRESS            4801 non-null   object
#  15  LATITUDE                     4801 non-null   float64
#  16  LONGITUDE                    4801 non-null   float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 637.8+ KB

# %% [markdown]
# ## Endereço com 0 banheiros? Vejamos!

# %%
df.loc[df['BATH']==0]
# Out:
#                            BROKERTITLE                TYPE     PRICE  BEDS  \
# 2699               Brokered by COMPASS             Pending    675000     3
# 2704               Brokered by COMPASS             Pending    675000     3
# 3379  Brokered by Brown Harris Stevens  Townhouse for sale  14995000     3
#
#       BATH  PROPERTYSQFT                      ADDRESS                STATE  \
# 2699   0.0   2780.000000       41 Warren St Unit Subc  Manhattan, NY 10007
# 2704   0.0   2780.000000       41 Warren St Unit Subc  Manhattan, NY 10007
# 3379   0.0   2184.207862  50 W 86th St Unit Townhouse  Manhattan, NY 10024
#
#                                         MAIN_ADDRESS  \
# 2699       41 Warren St Unit SubcManhattan, NY 10007
# 2704       41 Warren St Unit SubcManhattan, NY 10007
# 3379  50 W 86th St Unit TownhouseManhattan, NY 10024
#
#      ADMINISTRATIVE_AREA_LEVEL_2         LOCALITY      SUBLOCALITY  \
# 2699                    New York  New York County         New York
# 2704                    New York  New York County         New York
# 3379               United States         New York  New York County
#
#      STREET_NAME         LONG_NAME                        FORMATTED_ADDRESS  \
# 2699   Manhattan                41  41 Warren St b, New York, NY 10007, USA
# 2704   Manhattan                41  41 Warren St b, New York, NY 10007, USA
# 3379    New York  West 86th Street    50 W 86th St, New York, NY 10024, USA
#
#        LATITUDE  LONGITUDE
# 2699  40.714393 -74.008877
# 2704  40.714393 -74.008877
# 3379  40.786046 -73.971834

# %% [markdown]
# Os _ids_ `2699` e `2704` parecem duplicados. São mesmo?

# %%
df.iloc[2699].equals(df.iloc[2704])
# Out:
# True

# %% [markdown]
# Sim! Esses dados estão duplicados! Será que existem mais?

# %%
df[df.duplicated(keep=False)]
# Out:
#                                             BROKERTITLE  \
# 80        Brokered by Douglas Elliman - 575 Madison Ave
# 81        Brokered by Douglas Elliman - 575 Madison Ave
# 113                              Brokered by Sowae Corp
# 114                              Brokered by Sowae Corp
# 115                              Brokered by Sowae Corp
# ...                                                 ...
# 4760                                           NoBroker
# 4770  Brokered by Sotheby's International Realty - E...
# 4775                    Brokered by EXIT REALTY PREMIER
# 4780                                           NoBroker
# 4782  Brokered by Sotheby's International Realty - E...
#
#                             TYPE    PRICE  BEDS      BATH  PROPERTYSQFT  \
# 80                Condo for sale  1650000     2  2.000000   1065.000000
# 81                Condo for sale  1650000     2  2.000000   1065.000000
# 113               House for sale   400000     4  2.000000   1980.000000
# 114   Multi-family home for sale   346000     5  2.000000   2184.207862
# 115               House for sale   400000     4  2.000000   1980.000000
# ...                          ...      ...   ...       ...           ...
# 4760  Multi-family home for sale  2000000     8  2.373861   2184.207862
# 4770              Condo for sale  2600000     3  2.000000   1729.000000
# 4775              House for sale   749000     3  2.373861   2002.000000
# 4780  Multi-family home for sale  2000000     8  2.373861   2184.207862
# 4782              Condo for sale  2600000     3  2.000000   1729.000000
#
#                     ADDRESS                 STATE  \
# 80    200 E 94th St Apt 414    New York, NY 10128
# 81    200 E 94th St Apt 414    New York, NY 10128
# 113         781 Sheperd Ave    Brooklyn, NY 11208
# 114         103-12 104th St  Ozone Park, NY 11417
# 115         781 Sheperd Ave    Brooklyn, NY 11208
# ...                     ...                   ...
# 4760           2324 60th St    Brooklyn, NY 11204
# 4770    242 E 15th St Apt 1    New York, NY 10003
# 4775           631 Essex St    Brooklyn, NY 11208
# 4780           2324 60th St    Brooklyn, NY 11204
# 4782    242 E 15th St Apt 1    New York, NY 10003
#
#                                  MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 80    200 E 94th St Apt 414New York, NY 10128                    New York
# 81    200 E 94th St Apt 414New York, NY 10128                    New York
# 113         781 Sheperd AveBrooklyn, NY 11208               United States
# 114       103-12 104th StOzone Park, NY 11417               United States
# 115         781 Sheperd AveBrooklyn, NY 11208               United States
# ...                                       ...                         ...
# 4760           2324 60th StBrooklyn, NY 11204               United States
# 4770    242 E 15th St Apt 1New York, NY 10003                    New York
# 4775           631 Essex StBrooklyn, NY 11208               United States
# 4780           2324 60th StBrooklyn, NY 11204               United States
# 4782    242 E 15th St Apt 1New York, NY 10003                    New York
#
#              LOCALITY    SUBLOCALITY STREET_NAME        LONG_NAME  \
# 80    New York County       New York   Manhattan              200
# 81    New York County       New York   Manhattan              200
# 113          New York   Kings County    Brooklyn  Shepherd Avenue
# 114          New York  Queens County      Queens     104th Street
# 115          New York   Kings County    Brooklyn  Shepherd Avenue
# ...               ...            ...         ...              ...
# 4760         New York   Kings County    Brooklyn      60th Street
# 4770  New York County       New York   Manhattan              242
# 4775         New York   Kings County    Brooklyn     Essex Street
# 4780         New York   Kings County    Brooklyn      60th Street
# 4782  New York County       New York   Manhattan              242
#
#                                    FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 80    200 E 94th St APT 414, New York, NY 10128, USA  40.783355 -73.949998
# 81    200 E 94th St APT 414, New York, NY 10128, USA  40.783355 -73.949998
# 113        781 Shepherd Ave, Brooklyn, NY 11208, USA  40.665357 -73.877087
# 114          103-12 104th St, Jamaica, NY 11417, USA  40.683789 -73.838104
# 115        781 Shepherd Ave, Brooklyn, NY 11208, USA  40.665357 -73.877087
# ...                                              ...        ...        ...
# 4760           2324 60th St, Brooklyn, NY 11204, USA  40.614758 -73.975714
# 4770    242 E 15th St APT 1, New York, NY 10003, USA  40.733031 -73.985037
# 4775           631 Essex St, Brooklyn, NY 11208, USA  40.668173 -73.880027
# 4780           2324 60th St, Brooklyn, NY 11204, USA  40.614758 -73.975714
# 4782    242 E 15th St APT 1, New York, NY 10003, USA  40.733031 -73.985037
#
# [427 rows x 17 columns]

# %% [markdown]
# Vamos remover os dados duplicados, mantendo apenas uma instância de cada um deles.

# %%
df_filtered = df.drop_duplicates()
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4587 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4587 non-null   object
#  1   TYPE                         4587 non-null   object
#  2   PRICE                        4587 non-null   int64
#  3   BEDS                         4587 non-null   int64
#  4   BATH                         4587 non-null   float64
#  5   PROPERTYSQFT                 4587 non-null   float64
#  6   ADDRESS                      4587 non-null   object
#  7   STATE                        4587 non-null   object
#  8   MAIN_ADDRESS                 4587 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4587 non-null   object
#  10  LOCALITY                     4587 non-null   object
#  11  SUBLOCALITY                  4587 non-null   object
#  12  STREET_NAME                  4587 non-null   object
#  13  LONG_NAME                    4587 non-null   object
#  14  FORMATTED_ADDRESS            4587 non-null   object
#  15  LATITUDE                     4587 non-null   float64
#  16  LONGITUDE                    4587 non-null   float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 645.0+ KB

# %%
df_filtered.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  4.587000e+03  4587.000000  4587.000000   4587.000000  4587.000000
# mean   2.381172e+06     3.365816     2.377735   2177.712426    40.713932
# std    3.206831e+07     2.628808     1.968503   2283.095559     0.087738
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.638588
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726667
# 75%    1.498500e+06     4.000000     3.000000   2184.207862    40.771913
# max    2.147484e+09    50.000000    50.000000  65535.000000    40.912729
#
#          LONGITUDE
# count  4587.000000
# mean    -73.941584
# std       0.101276
# min     -74.253033
# 25%     -73.987420
# 50%     -73.949116
# 75%     -73.869455
# max     -73.702450

# %% [markdown]
# ##Parece estranho também um imóvel acima de U$2 bilhões. Seria um registro válido?

# %%
property_most_valued = df_filtered[df_filtered['PRICE'] == df_filtered['PRICE'].max()]
property_most_valued
# Out:
#                            BROKERTITLE            TYPE       PRICE  BEDS  \
# 304  Brokered by ANNE LOPA REAL ESTATE  House for sale  2147483647     7
#
#      BATH  PROPERTYSQFT             ADDRESS               STATE  \
# 304   6.0       10000.0  6659-6675 Amboy Rd  New York, NY 10309
#
#                              MAIN_ADDRESS ADMINISTRATIVE_AREA_LEVEL_2  \
# 304  6659-6675 Amboy RdNew York, NY 10309               United States
#
#      LOCALITY      SUBLOCALITY    STREET_NAME   LONG_NAME  \
# 304  New York  Richmond County  Staten Island  Amboy Road
#
#                                FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 304  6659 Amboy Rd, Staten Island, NY 10309, USA  40.518484 -74.224418

# %%
df_richmond = df_filtered[df_filtered['SUBLOCALITY'] == 'Richmond County']

df_richmond.sort_values(by='PRICE', ascending=False).head(5)
# Out:
#                                 BROKERTITLE                        TYPE  \
# 304       Brokered by ANNE LOPA REAL ESTATE              House for sale
# 7         Brokered by Connie Profaci Realty              House for sale
# 2653        Brokered by NEUHAUS REALTY INC.  Multi-family home for sale
# 3524  Brokered by Corcoran Brooklyn Heights              House for sale
# 1295        Brokered by Joanne Costa Realty  Multi-family home for sale
#
#            PRICE  BEDS       BATH  PROPERTYSQFT                    ADDRESS  \
# 304   2147483647     7   6.000000  10000.000000         6659-6675 Amboy Rd
# 7       16800000     8  16.000000  33000.000000            177 Benedict Rd
# 2653    10700000    42  43.000000  27152.000000  646-662 Port Richmond Ave
# 3524     6700000     3   2.373861   2184.207862               450 Front St
# 1295     3995000     3   2.373861  12200.000000           639 Tompkins Ave
#
#                         STATE  \
# 304        New York, NY 10309
# 7     Staten Island, NY 10304
# 2653  Staten Island, NY 10302
# 3524  Staten Island, NY 10304
# 1295  Staten Island, NY 10305
#
#                                           MAIN_ADDRESS  \
# 304               6659-6675 Amboy RdNew York, NY 10309
# 7               177 Benedict RdStaten Island, NY 10304
# 2653  646-662 Port Richmond AveStaten Island, NY 10302
# 3524               450 Front StStaten Island, NY 10304
# 1295           639 Tompkins AveStaten Island, NY 10305
#
#      ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY    STREET_NAME  \
# 304                United States  New York  Richmond County  Staten Island
# 7                  United States  New York  Richmond County  Staten Island
# 2653               United States  New York  Richmond County  Staten Island
# 3524               United States  New York  Richmond County  Staten Island
# 1295               United States  New York  Richmond County  Staten Island
#
#                  LONG_NAME                                  FORMATTED_ADDRESS  \
# 304             Amboy Road        6659 Amboy Rd, Staten Island, NY 10309, USA
# 7            Benedict Road      177 Benedict Rd, Staten Island, NY 10304, USA
# 2653  Port Richmond Avenue  646 Port Richmond Ave, Staten Island, NY 10302...
# 3524          Front Street         450 Front St, Staten Island, NY 10304, USA
# 1295       Tompkins Avenue    639 Tompkins Ave., Staten Island, NY 10305, USA
#
#        LATITUDE  LONGITUDE
# 304   40.518484 -74.224418
# 7     40.595002 -74.106424
# 2653  40.627671 -74.142352
# 3524  40.626225 -74.074564
# 1295  40.610728 -74.070161

# %% [markdown]
# ##Aqui ficou claro que o outlier de preço é um registro errado, já que casas da mesma área com mais quartos, metros quadrados e banheiros têm um preço muito menor. Agora, vamos investigar o outlier da metragem.

# %% [markdown]
# ##Há outros imóveis do tipo que têm uma área maior, então não parece ser outro caso de registro errado. Agora, vamos limpar a base do registro errado.

# %%
df_filtered = df_filtered[df_filtered['PRICE'] != 2147483647]

# %%
df_filtered.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  4.586000e+03  4586.000000  4586.000000   4586.000000  4586.000000
# mean   1.913421e+06     3.365024     2.376945   2176.006738    40.713975
# std    4.979040e+06     2.628547     1.967990   2280.419696     0.087700
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.638624
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726691
# 75%    1.497250e+06     4.000000     3.000000   2184.207862    40.771913
# max    1.950000e+08    50.000000    50.000000  65535.000000    40.912729
#
#          LONGITUDE
# count  4586.000000
# mean    -73.941523
# std       0.101201
# min     -74.253033
# 25%     -73.987387
# 50%     -73.949116
# 75%     -73.869418
# max     -73.702450

# %% [markdown]
# ## Visualizações

# %% [markdown]
# ### Histogramas

# %%
cols = ['PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT']

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

axs_flat = axs.flatten()

for idx, col in enumerate(cols):
    sns.histplot(
        data=df_filtered[col],
        ax=axs_flat[idx],
        log_scale=True if col == 'PRICE' or col == 'PROPERTYSQFT' else False,
        kde=True if col == 'PRICE' or col == 'PROPERTYSQFT' else False
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot

# %%
cols = ['PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT']

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

axs_flat = axs.flatten()

for idx, col in enumerate(cols):
    sns.boxplot(
        data=df_filtered[col],
        ax=axs_flat[idx],
        log_scale=True,
    )
    axs_flat[idx].plot(df_filtered[col].mean(), 'r.')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matriz de Correlação

# %%
corr = df_filtered.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5
)
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# ##Há uma correlação aparente forte entre a área do imóvel, o número de quartos e banheiros, o que faz muito sentido.

# %% [markdown]
# ## Análise aprofundada: `PROPERTYSQFT`

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
sns.histplot(df_filtered['PROPERTYSQFT'], ax=axs[0], log_scale=True, bins=10)
sns.boxplot(df_filtered['PROPERTYSQFT'], ax=axs[1], orient='h')

plt.show()

# %%
df_filtered['PROPERTYSQFT'].max()
# Out:
# 65535.0

# %% [markdown]
# O valor máximo em `PROPERTYSQFT` (65535) é o maior valor possível para um _inteiro de 16 bits sem sinal_. Dessa forma, pode ser um erro.

# %% [markdown]
# ## Análise aprofundada: `TYPE`

# %%
types = df_filtered.groupby('TYPE').agg({
    'PRICE': 'count',
}).reset_index().rename(columns={'PRICE': 'Quantidade'}).sort_values(by='Quantidade', ascending=False)

ax = types.plot(
    kind='barh',
    x='TYPE',
    y='Quantidade',
    legend=False
)

ax.invert_yaxis()
ax.set_xlim(0, 1600)

for i, (index, row) in enumerate(types.iterrows()):
    ax.text(row['Quantidade'] + 1, i, str(row['Quantidade']), va='center')

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df_filtered.groupby('TYPE').agg({
    'PRICE': 'count',
}).reset_index().rename(columns={'PRICE': 'Quantidade'}).sort_values(by='Quantidade', ascending=False)
# Out:
#                           TYPE  Quantidade
# 0               Co-op for sale        1388
# 7               House for sale         965
# 2               Condo for sale         842
# 10  Multi-family home for sale         699
# 12          Townhouse for sale         288
# 11                     Pending         229
# 4                   Contingent          87
# 8                Land for sale          47
# 5                     For sale          20
# 6                  Foreclosure          14
# 3              Condop for sale           4
# 1                  Coming Soon           2
# 9        Mobile house for sale           1

# %% [markdown]
# ## Visualização Geográfica

# %%
import plotly.express as px

fig = px.scatter_mapbox(
    df_filtered,
    lat="LATITUDE",
    lon="LONGITUDE",
    color="PRICE",
    size="PROPERTYSQFT",
    hover_data=["PRICE", "BEDS", "BATH"],
    zoom=10,
    height=600
)

fig.update_layout(mapbox_style="open-street-map")

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01bda166-f4a5-4b81-bc72-3b05a81eca53" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01bda166-f4a5-4b81-bc72-3b05a81eca53")) {                    Plotly.newPlot(                        "01bda166-f4a5-4b81-bc72-3b05a81eca53",                        [{"customdata":[[315000.0,2.0,2.0],[195000000.0,7.0,10.0],[260000.0,4.0,2.0],[69000.0,3.0,1.0],[55000000.0,7.0,2.3738608579684373],[690000.0,5.0,2.0],[899500.0,2.0,2.0],[16800000.0,8.0,16.0],[265000.0,1.0,1.0],[440000.0,2.0,1.0],[375000.0,2.0,1.0],[689000.0,3.0,2.3738608579684373],[259000.0,3.0,1.0],[430000.0,2.0,2.0],[895000.0,3.0,1.0],[549000.0,2.0,2.0],[975000.0,3.0,2.0],[199000.0,3.0,1.0],[350000.0,1.0,1.0],[599000.0,2.0,2.0],[639999.0,3.0,2.0],[1300000.0,2.0,2.0],[1100000.0,6.0,3.0],[349900.0,1.0,1.0],[750000.0,2.0,2.0],[1690000.0,6.0,4.0],[325000.0,1.0,1.0],[2250000.0,12.0,2.3738608579684373],[230000.0,1.0,1.0],[1299888.0,10.0,6.0],[925000.0,5.0,2.0],[329000.0,1.0,2.0],[1300000.0,10.0,8.0],[848000.0,5.0,4.0],[279000.0,1.0,1.0],[528000.0,1.0,1.0],[1299888.0,11.0,4.0],[275000.0,1.0,1.0],[1165000.0,1.0,1.0],[1199000.0,6.0,5.0],[700000.0,6.0,2.0],[2150000.0,8.0,4.0],[1280000.0,7.0,5.0],[199900.0,1.0,1.0],[369000.0,2.0,1.0],[699000.0,4.0,3.0],[4250000.0,3.0,2.0],[825000.0,2.0,2.0],[329000.0,2.0,1.0],[889000.0,2.0,2.0],[769000.0,2.0,2.0],[1200000.0,4.0,2.0],[220500.0,2.0,1.0],[1999000.0,3.0,3.0],[3250000.0,2.0,2.0],[1650000.0,2.0,2.0],[1049000.0,4.0,4.0],[998800.0,3.0,4.0],[998800.0,3.0,4.0],[3150000.0,3.0,2.0],[849000.0,1.0,1.0],[559500.0,1.0,1.0],[750000.0,1.0,1.0],[1900000.0,2.0,2.0],[1250000.0,2.0,2.0],[1395000.0,2.0,2.0],[198000.0,1.0,1.0],[619888.0,3.0,2.0],[1489000.0,6.0,2.3738608579684373],[65000000.0,3.0,2.3738608579684373],[1595000.0,3.0,3.0],[655000.0,3.0,2.0],[1175000.0,2.0,2.0],[2880000.0,9.0,2.3738608579684373],[798000.0,3.0,4.0],[1685000.0,3.0,2.3738608579684373],[31000000.0,3.0,4.0],[2550000.0,3.0,2.3738608579684373],[119000.0,3.0,2.3738608579684373],[269000.0,5.0,2.0],[1650000.0,2.0,2.0],[12950000.0,5.0,4.0],[5750000.0,3.0,2.0],[250000.0,5.0,2.0],[950000.0,6.0,2.3738608579684373],[585000.0,3.0,2.0],[8750000.0,6.0,6.0],[595000.0,3.0,1.0],[215000.0,1.0,1.0],[950000.0,1.0,1.0],[314000.0,3.0,1.0],[395000.0,5.0,1.0],[600000.0,2.0,2.0],[790000.0,6.0,3.0],[539000.0,2.0,2.0],[1295000.0,4.0,2.0],[245000.0,3.0,1.0],[400000.0,7.0,3.0],[55000000.0,8.0,8.0],[280000.0,1.0,1.0],[899000.0,3.0,2.0],[2280000.0,2.0,2.0],[649000.0,4.0,3.0],[739000.0,6.0,4.0],[1495000.0,4.0,2.3738608579684373],[3950000.0,5.0,2.0],[325000.0,2.0,1.0],[299999.0,3.0,1.0],[2695000.0,6.0,5.0],[4800000.0,6.0,2.3738608579684373],[694000.0,3.0,3.0],[688888.0,4.0,2.0],[400000.0,4.0,2.0],[346000.0,5.0,2.0],[265000.0,3.0,1.0],[319000.0,3.0,2.0],[24800000.0,6.0,8.0],[1100000.0,9.0,4.0],[309000.0,6.0,2.0],[650000.0,3.0,2.0],[799000.0,4.0,2.0],[259000.0,3.0,2.0],[1195000.0,4.0,4.0],[17500000.0,5.0,6.0],[189000.0,2.0,2.0],[759000.0,3.0,2.0],[275000.0,4.0,1.0],[499000.0,1.0,1.0],[1249000.0,3.0,2.3738608579684373],[69900.0,2.0,1.0],[1150000.0,12.0,6.0],[1749900.0,5.0,4.0],[1399000.0,3.0,4.0],[649000.0,3.0,2.0],[499000.0,5.0,2.0],[1050000.0,5.0,4.0],[5000000.0,10.0,9.0],[90000.0,1.0,1.0],[56000000.0,11.0,10.0],[650000.0,3.0,2.3738608579684373],[500000.0,4.0,3.0],[350000.0,2.0,1.0],[1099000.0,4.0,2.0],[90000.0,1.0,1.0],[839000.0,4.0,2.0],[659000.0,8.0,3.0],[399999.0,3.0,1.0],[250000.0,3.0,1.0],[1740000.0,2.0,2.0],[650000.0,4.0,2.0],[1165000.0,3.0,4.0],[729900.0,3.0,2.0],[1880000.0,3.0,4.0],[449000.0,2.0,2.0],[1175000.0,3.0,2.0],[2750000.0,3.0,2.0],[995000.0,3.0,2.0],[2000000.0,3.0,2.0],[15000000.0,8.0,6.0],[2800000.0,4.0,6.0],[2600000.0,5.0,4.0],[3500000.0,6.0,6.0],[550000.0,1.0,1.0],[769000.0,3.0,4.0],[675000.0,3. ...

# %% [markdown]
# **Análise de Preços por Região**

# %%
fig, ax = plt.subplots(figsize=(20,12))

preco_medio = df_filtered.groupby('SUBLOCALITY')['PRICE'].mean().sort_values(ascending=False)

preco_medio = preco_medio.reset_index()

sns.barplot(
    x='SUBLOCALITY',
    y='PRICE',
    data=preco_medio,
    palette='Blues_d',
    ax=ax,
    hue='SUBLOCALITY'
)

ax.set_title('Preço médio por bairro/distrito em Nova York, em Milhões de Dólares ($)', loc='left', fontsize=18)
ax.set_xlabel('Localidade')
ax.set_ylabel('Preço Médio ($)')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(labelleft=False)
ax.grid(False)

for i in range(preco_medio.shape[0]):
    ax.text(
        i,
        preco_medio['PRICE'][i] + preco_medio['PRICE'].max()*.01,
        f"{preco_medio['PRICE'][i]/1000000:.2f}",
        fontsize=12,
        color='black',
        ha='center'
    )


plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Imóveis mais valorizados**

# %%
imoveis_valorizados = df_filtered.sort_values(by='PRICE', ascending=False)

imoveis_valorizados.head(10)
# Out:
#                                             BROKERTITLE                TYPE  \
# 1                                   Brokered by Serhant      Condo for sale
# 69    Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 1075                                Brokered by COMPASS      Co-op for sale
# 141       Brokered by Douglas Elliman - 575 Madison Ave      House for sale
# 99        Brokered by Douglas Elliman - 575 Madison Ave      House for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 626     Brokered by Nest Seekers International, Midtown      Condo for sale
# 1453                     Brokered by Corcoran East Side      Co-op for sale
# 3388  Brokered by Sotheby's International Realty - E...      Co-op for sale
# 3571  Brokered by Sotheby's International Realty - E...      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# 1     195000000     7  10.000000  17545.000000
# 69     65000000     3   2.373861  15200.000000
# 1075   60000000     8   8.000000   2184.207862
# 141    56000000    11  10.000000  24000.000000
# 99     55000000     8   8.000000  12000.000000
# 4      55000000     7   2.373861  14175.000000
# 626    50000000     6   6.000000   6569.000000
# 1453   48000000     5   2.373861   2184.207862
# 3388   45000000     5   2.373861   2184.207862
# 3571   44500000     5   6.000000   2184.207862
#
#                                                 ADDRESS                STATE  \
# 1     Central Park Tower Penthouse-217 W 57th New Yo...   New York, NY 10019
# 69                                          4 E 79th St   New York, NY 10075
# 1075                                960 5th Ave Unit 12  Manhattan, NY 10075
# 141                                         9 W 54th St   New York, NY 10019
# 99                                      25 Riverside Dr   New York, NY 10023
# 4                                           5 E 64th St   New York, NY 10065
# 626                               100 Vandam St Apt 20A   New York, NY 10013
# 1453                              740 Park Ave # 4 & 5B   New York, NY 10021
# 3388                                   4 E 66th St Fl 7   New York, NY 10065
# 3571                                   2 E 67th St Fl 9   New York, NY 10065
#
#                                            MAIN_ADDRESS  \
# 1     Central Park Tower Penthouse-217 W 57th New Yo...
# 69                        4 E 79th StNew York, NY 10075
# 1075             960 5th Ave Unit 12Manhattan, NY 10075
# 141                       9 W 54th StNew York, NY 10019
# 99                    25 Riverside DrNew York, NY 10023
# 4                         5 E 64th StNew York, NY 10065
# 626             100 Vandam St Apt 20ANew York, NY 10013
# 1453            740 Park Ave # 4 & 5BNew York, NY 10021
# 3388                 4 E 66th St Fl 7New York, NY 10065
# 3571                 2 E 67th St Fl 9New York, NY 10065
#
#      ADMINISTRATIVE_AREA_LEVEL_2         LOCALITY      SUBLOCALITY  \
# 1                  United States         New York  New York County
# 69                 United States         New York  New York County
# 1075                    New York  New York County         New York
# 141                United States         New York  New York County
# 99                 United States         New York  New York County
# 4                  United States         New York  New York County
# 626                     New York  New York County         New York
# 1453                    New York  New York County         New York
# 3388                    New York  New York County         New York
# 3571                    New York  New York County         New York
#
#      STREET_NAME         LONG_NAME  \
# 1       New York  West 57th Street
# 69      New York  East 79th Street
# 1075   Manhattan               960
# 141     New York  West 54th Street
# 99      New York   Riverside Drive
# 4       New York  East 64th Street
# 626    Manhattan               100
# 1453   Manhattan               740
# 3388   Manhattan                 4
# 3571   Manhattan                 2
#
#                                 FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 1          217 W 57th St, New York, NY 10019, USA  40.766393 -73.980991
# 69           4 E 79th St, New York, NY 10075, USA  40.776561 -73.963317
# 1075     960 5th Ave #12, New York, NY 10075, USA  40.775642 -73.964247
# 141          9 W 54th St, New York, NY 10019, USA  40.761600 -73.976191
# 99       25 Riverside Dr, New York, NY 10023, USA  40.782238 -73.984632
# 4            5 E 64th St, New York, NY 10065, USA  40.767224 -73.969856
# 626   100 Vandam St #20a, New York, NY 10013, USA  40.726633 -74.008832
# 1453     740 Park Ave #5, New York, NY 10021, USA  40.770752 -73.964528
# 3388    4 E 66th St Fl 7, New York, NY 10065, USA  40.768301 -73.969734
# 3571    2 E 67th St Fl 9, New York, NY 10065, USA  40.768973 -73.969136

# %% [markdown]
# **Venda por Tipo de Imóvel**

# %%
fig, ax = plt.subplots(figsize=(16,6))

preco_medio = df_filtered.groupby('TYPE')['PRICE'].mean().sort_values(ascending=False)

preco_medio = preco_medio.reset_index()

sns.barplot(
    x='TYPE',
    y='PRICE',
    data=preco_medio,
    palette='Blues_d',
    ax=ax,
    hue='TYPE'
)

ax.set_title('Preço médio por tipo de imóvel em Nova York, em Milhões de Dólares ($)', loc='left', fontsize=18)
ax.set_xlabel('Tipo de Imóvel')
ax.set_ylabel('Preço Médio ($)')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(labelleft=False)
ax.grid(False)

for i in range(preco_medio.shape[0]):
    ax.text(
        i,
        preco_medio['PRICE'][i] + preco_medio['PRICE'].max()*.01,
        f"{preco_medio['PRICE'][i]/1000000:.2f}",
        fontsize=12,
        color='black',
        ha='center'
    )


plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
townhouses = df_filtered[df_filtered['TYPE'].str.contains('Townhouse', case=False, na=False)]

townhouses_por_preco = townhouses.sort_values(by='PRICE', ascending=False)

townhouses_por_preco.head(10)
# Out:
#                                             BROKERTITLE                TYPE  \
# 69    Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 181                                 Brokered by COMPASS  Townhouse for sale
# 631   Brokered by Sotheby's International Realty - D...  Townhouse for sale
# 222        Brokered by CHRISTIE'S INT.REAL ESTATE GROUP  Townhouse for sale
# 601   Brokered by Peter Ashe Real Estate- Peter Ashe...  Townhouse for sale
# 1990        Brokered by Garfield, Leslie J. & Co., Inc.  Townhouse for sale
# 3007                                Brokered by Serhant  Townhouse for sale
# 776   Brokered by Sotheby's International Realty - D...  Townhouse for sale
# 917                                 Brokered by COMPASS  Townhouse for sale
#
#          PRICE  BEDS       BATH  PROPERTYSQFT                      ADDRESS  \
# 69    65000000     3   2.373861  15200.000000                  4 E 79th St
# 4     55000000     7   2.373861  14175.000000                  5 E 64th St
# 181   39995000     4   2.373861  10582.000000                 145 Reade St
# 631   29950000    10  13.000000   8750.000000           26 Washington Sq N
# 222   29200000    12  10.000000  11638.000000                123 E 35th St
# 601   28500000     7   9.000000  12300.000000  14 E 69th St Unit Townhouse
# 1990  27000000     5   7.000000   2184.207862             64-66 Bedford St
# 3007  26000000     8   6.000000  10940.000000                 23 E 67th St
# 776   25500000     5   2.373861   2184.207862             763 Greenwich St
# 917   25000000     7   2.373861  20000.000000                 11 Hubert St
#
#                     STATE                                   MAIN_ADDRESS  \
# 69     New York, NY 10075                  4 E 79th StNew York, NY 10075
# 4      New York, NY 10065                  5 E 64th StNew York, NY 10065
# 181   Manhattan, NY 10013                145 Reade StManhattan, NY 10013
# 631    New York, NY 10011           26 Washington Sq NNew York, NY 10011
# 222    New York, NY 10016                123 E 35th StNew York, NY 10016
# 601    New York, NY 10021  14 E 69th St Unit TownhouseNew York, NY 10021
# 1990   New York, NY 10014             64-66 Bedford StNew York, NY 10014
# 3007   New York, NY 10065                 23 E 67th StNew York, NY 10065
# 776    New York, NY 10014             763 Greenwich StNew York, NY 10014
# 917   Manhattan, NY 10013                11 Hubert StManhattan, NY 10013
#
#      ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY STREET_NAME  \
# 69                 United States  New York  New York County    New York
# 4                  United States  New York  New York County    New York
# 181                United States  New York  New York County    New York
# 631                United States  New York  New York County    New York
# 222                United States  New York  New York County    New York
# 601                United States  New York  New York County    New York
# 1990               United States  New York  New York County    New York
# 3007               United States  New York  New York County    New York
# 776                United States  New York  New York County    New York
# 917                United States  New York  New York County    New York
#
#                    LONG_NAME                                FORMATTED_ADDRESS  \
# 69          East 79th Street             4 E 79th St, New York, NY 10075, USA
# 4           East 64th Street             5 E 64th St, New York, NY 10065, USA
# 181             Reade Street            145 Reade St, New York, NY 10013, USA
# 631   Washington Square West  26 Washington Square W, New York, NY 10011, USA
# 222         East 35th Street           123 E 35th St, New York, NY 10016, USA
# 601         East 69th Street            14 E 69th St, New York, NY 10021, USA
# 1990          Bedford Street           64 Bedford St, New York, NY 10014, USA
# 3007        East 67th Street            23 E 67th St, New York, NY 10065, USA
# 776         Greenwich Street        763 Greenwich St, New York, NY 10014, USA
# 917            Hubert Street            11 Hubert St, New York, NY 10013, USA
#
#        LATITUDE  LONGITUDE
# 69    40.776561 -73.963317
# 4     40.767224 -73.969856
# 181   40.716422 -74.010120
# 631   40.732221 -73.998628
# 222   40.747472 -73.979679
# 601   40.769934 -73.967507
# 1990  40.731228 -74.004615
# 3007  40.768870 -73.967875
# 776   40.736118 -74.006487
# 917   40.721329 -74.009256

# %% [markdown]
# Como _townhouses_ têm um valor médio mais significativo com relação aos outros tipos de imóveis, agora investigaremos a matriz de correlação para tentar identificar algum padrão.

# %%
townhouses = df_filtered[df_filtered['TYPE'].str.contains('Townhouse', case=False, na=False)]

corr_townhouse = townhouses.select_dtypes(include='number').corr()

plt.figure(figsize=(10, 8))
sns.heatmap(
    corr_townhouse,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5,
    fmt='.2f'
)
plt.title('Matriz de Correlação - Townhouses')
plt.show()

# %% [markdown]
# E os outros tipos de imóveis, teriam a as mesmas correlações?

# %%
tipos_excluir = ['Mobile house for sale', 'Land for sale', 'Condop for sale', 'Coming Soon']

tipos_imovel = [tipo for tipo in df_filtered['TYPE'].dropna().unique() if tipo not in tipos_excluir]

n_cols = 2
n = len(tipos_imovel)
n_rows = int(np.ceil(n / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

axes = np.array(axes).reshape(n_rows, n_cols)

for idx, tipo in enumerate(tipos_imovel):
    row = idx // n_cols
    col = idx % n_cols
    ax = axes[row, col]

    df_tipo = df_filtered[df_filtered['TYPE'].str.contains(tipo, case=False, na=False)]
    corr_tipo = df_tipo.select_dtypes(include='number').corr()

    if not corr_tipo.empty:
        sns.heatmap(
            corr_tipo,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5,
            fmt='.2f',
            ax=ax
        )
        ax.set_title(f'Matriz de Correlação - {tipo}')
    else:
        ax.axis('off')
        ax.set_title(f'Sem dados numéricos - {tipo}')

for i in range(idx + 1, n_rows * n_cols):
    row = i // n_cols
    col = i % n_cols
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hipóteses

# %% [markdown]
# ## Os maiores terrenos têm os maiores valores?

# %% [markdown]
# ## Os imóveis mais valorizados têm mais banheiros e quartos?

# %% [markdown]
# ## O tipo de imóvel influencia nos valores?

# %%
types_property = df_filtered['TYPE'].unique()

price_list_townhouses = df_filtered[df_filtered['TYPE'] == "Townhouse for sale"]['PRICE']
price_list_condo = df_filtered[df_filtered['TYPE'] == "Condo for sale"]['PRICE']
price_list_for_sale = df_filtered[df_filtered['TYPE'] == "For sale"]['PRICE']

stat, p = stats.levene(price_list_townhouses, price_list_condo, price_list_for_sale)

print(f'Estatística de Levene: {stat:.4f}')
print(f'Valor-p: {p}')

if p > 0.05:
    print("Não há evidências de diferença significativa nas variâncias.")
else:
    print("As variâncias são significativamente diferentes entre os tipos de imóvel.")

# Kruskal-Wallis
print("\nComo o valor ficou abaixo de 5%, utilizaremos o teste de Kruskal-Wallis")
k_stats, k_val = stats.kruskal(price_list_townhouses, price_list_condo, price_list_for_sale)

print(f'Estatísca da Kruskal-Wallis: { k_stats} P valor: {k_val}')

if k_val  > 0.05:
    print("Os métodos de ensino não apresentam diferenças significativas (falha em rejeitar h0)")
else:
    print("Os métodos apresentam diferenças significativas (rejeita-se h0)")

df_box = pd.DataFrame({
    'Townhouse for sale': price_list_townhouses,
    'Condo for sale': price_list_condo,
    'For sale': price_list_for_sale
})

sns.boxplot(data=df_box)
plt.title("Distribuição dos Preços por Tipo de Imóvel")
plt.ylabel("Preço ($)")
plt.xlabel("Tipo de Imóvel")
plt.show()

pd.DataFrame({
    'Townhouse for sale': price_list_townhouses,
    'Condo for sale': price_list_condo,
    'For sale': price_list_for_sale
}).describe()
# Out:
# Estatística de Levene: 15.9223
# Valor-p: 1.5110241376932852e-07
# As variâncias são significativamente diferentes entre os tipos de imóvel.
#
# Como o valor ficou abaixo de 5%, utilizaremos o teste de Kruskal-Wallis
# Estatísca da Kruskal-Wallis: 147.984747725381 P valor: 7.33703056880219e-33
# Os métodos apresentam diferenças significativas (rejeita-se h0)
#        Townhouse for sale  Condo for sale      For sale
# count        2.880000e+02    8.420000e+02  2.000000e+01
# mean         6.406234e+06    2.615780e+06  1.954536e+06
# std          8.346999e+06    7.936657e+06  1.875709e+06
# min          3.150000e+05    6.000000e+04  2.494000e+03
# 25%          1.283000e+06    5.750000e+05  8.110000e+05
# 50%          2.995000e+06    8.800000e+05  1.044500e+06
# 75%          8.106250e+06    2.150000e+06  2.812500e+06
# max          6.500000e+07    1.950000e+08  6.500000e+06

# %% [markdown]
# **Regressão Linear**

# %%
tipos_excluir = ['Mobile house for sale', 'Land for sale', 'Condop for sale', 'Coming Soon']

df_types = df_filtered[~df_filtered['TYPE'].isin(tipos_excluir)]

df_regressao = df_types[['PRICE', 'PROPERTYSQFT', 'BEDS', 'BATH']]

X = df_types[['PROPERTYSQFT', 'BEDS', 'BATH']]
y = df_types['PRICE']

reg = LinearRegression()
reg.fit(X, y)

print('Intercepto (β₀):', reg.intercept_)
print('Coeficientes (β):', reg.coef_)
print('Score R²:', reg.score(X, y))
# Out:
# Intercepto (β₀): -1388708.7361072758
# Coeficientes (β): [   1468.97607851 -437815.02454321  866571.35900492]
# Score R²: 0.014433511852040226
